# %% [markdown]
# <a href="https://colab.research.google.com/github/lcs123456/Learn-Datascience/blob/master/analise_retificadores6e12pulsos/Plotformas_de_onda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import math
import numpy as np
from copy import deepcopy as dc
from scipy.integrate import simps as inte

# %%
lista = np.arange(0,1,0.000001)

# %%
# Out:
# array([0.00000e+00, 1.00000e-06, 2.00000e-06, ..., 9.99997e-01,
#        9.99998e-01, 9.99999e-01])

# %%
def createlist(angulo = 0):
  a = []
  for x in lista:
    a.append(655*1.41*math.sin(x*366+math.radians(angulo)))
  senoides.append(a.copy())

# %%
senoides = []
createlist(-7.5)
createlist(112.5)
createlist(-127.5)
createlist(22.5)
createlist(142.5)
createlist(-97.5)

# %%
maxi=[]
mini=[]
for x in range(len(senoides[1])):
  list = [senoides[0][x],senoides[1][x],senoides[2][x],senoides[3][x],senoides[4][x],senoides[5][x]]
  maxi.append(max(list))
  mini.append(min(list))
maxi2=[]
mini2=[]
for x in range(len(senoides[1])):
  list = [senoides[0][x],senoides[1][x],senoides[2][x]]
  maxi2.append(max(list))
  mini2.append(min(list))
DC1=[]
for x in range(len(maxi)):
  list = [maxi[x],-mini[x]]
  DC1.append((max(list)*math.sqrt(3)))
DC2=[]
for x in range(len(maxi2)):
  list = [maxi2[x],-mini2[x]]
  DC2.append((max(list)*math.sqrt(3)))

# %%
plt.rcParams["figure.figsize"] = (30,10)
plt.plot(lista, senoides[0],lista, senoides[1],lista, senoides[2])
plt.axis([0,0.016667,-1000,1000])
plt.title("Ondas Trifásicas Normais", fontsize=20)
plt.xlabel("Tempo(s)", fontsize=15)
plt.ylabel("Tensão(V)", fontsize=15)
plt.show()

# %%
plt.rcParams["figure.figsize"] = (30,10)
plt.plot(lista, senoides[0],lista, senoides[1],lista, senoides[2],lista, senoides[3],lista, senoides[4],lista, senoides[5])
plt.axis([0,0.016667,-1000,1000])
plt.title("Onda com Duas Saídas Defasadas", fontsize=20)
plt.xlabel("Tempo(s)", fontsize=15)
plt.ylabel("Tensão(V)", fontsize=15)
plt.show()

# %%
plt.rcParams["figure.figsize"] = (30,10)
plt.plot(lista, maxi2,lista, mini2)
plt.axis([0,0.016667,-1000,1000])
plt.title("Área Ondas Trifásicas Normais", fontsize=20)
plt.xlabel("Tempo(s)", fontsize=15)
plt.ylabel("Tensão(V)", fontsize=15)
plt.show()

# %%
plt.rcParams["figure.figsize"] = (30,10)
plt.plot(lista, maxi,lista, mini)
plt.axis([0,0.016667,-1000,1000])
plt.title("Área Onda com Duas Saídas Defasadas", fontsize=20)
plt.xlabel("Tempo(s)", fontsize=15)
plt.ylabel("Tensão(Vca)", fontsize=15)
plt.show()

# %% [markdown]
# # Analise da Tensão DC.
# ### A tensão DC é baseada na soma entre os Picos da tensão mais negativa e mais positiva.
# A tensão pode ser calculada pela formula:
# # $V_{med}=\frac{1}{T}*\int_{\frac{\pi}{6}}^{\frac{2\pi}{6}}V_{12}(\omega t)\partial \omega t$
# # $V_{med}=\frac{3\sqrt{3}V_p}{\pi}\cong \sqrt{3}V_p$

# %%
plt.plot(lista,DC2)
plt.axis([0,0.016667,0,1700])
plt.title("Resposta DC Ondas Trifásicas Normais", fontsize=20)
plt.xlabel("Tempo(s)", fontsize=15)
plt.ylabel("Tensão(Vcc)", fontsize=15)
plt.show()

# %%
plt.plot(lista,DC1)
plt.axis([0,0.016667,0,1700])
plt.title("Resposta DC com Duas Saídas Defasadas", fontsize=20)
plt.xlabel("Tempo(s)", fontsize=15)
plt.ylabel("Tensão(Vcc)", fontsize=15)
plt.show()

# %%
plt.plot(lista,DC2)
plt.axis([0,1,0,1700])
plt.title("Resposta DC Ondas Trifásicas Normais Analise em Um Segundo", fontsize=20)
plt.xlabel("Tempo(s)", fontsize=15)
plt.ylabel("Tensão(Vcc)", fontsize=15)
ripple = max(DC2)-min(DC2)
plt.legend(['Ripple Médio: '+str(round(ripple/10,2))+'%'],fontsize=25, loc=10)
plt.show()

# %%
plt.plot(lista,DC1)
plt.axis([0,1,0,1700])
plt.title("Resposta DC com Duas Saidas Defasadas Analise em Um Segundo", fontsize=20)
plt.xlabel("Tempo(s)", fontsize=15)
plt.ylabel("Tensão(Vcc)", fontsize=15)
ripple = max(DC1)-min(DC1)
plt.legend(['Ripple Médio: '+str(round(ripple/10,2))+'%'],fontsize=25, loc=10)
plt.show()

# %%
min(DC1)
# Out:
# 1545.129403296398
